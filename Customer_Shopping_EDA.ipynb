# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from itertools import cycle
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')
color=plt.rcParams["axes.prop_cycle"].by_key()['color']
color_cycle=cycle(plt.rcParams["axes.prop_cycle"].by_key()['color'])

# %%
df=pd.read_csv("https://raw.githubusercontent.com/2k0v11/Dataset/main/customer_shopping_data.csv?token=GHSAT0AAAAAACIE3BYYLOOGXNFKPLQICZKGZJCRFVQ")
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card   05-08-2022          Kanyon
# 1     Debit Card   12-12-2021  Forum Istanbul
# 2           Cash   09-11-2021       Metrocity
# 3    Credit Card   16-05-2021    Metropol AVM
# 4           Cash   24-10-2021          Kanyon

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe().T.style.background_gradient(axis=1,cmap='Blues')
# Out:
# <style type="text/css">
# #T_82c43_row0_col0, #T_82c43_row1_col0, #T_82c43_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_82c43_row0_col1, #T_82c43_row0_col2, #T_82c43_row0_col3, #T_82c43_row0_col4, #T_82c43_row0_col5, #T_82c43_row0_col6, #T_82c43_row0_col7, #T_82c43_row1_col1, #T_82c43_row1_col2, #T_82c43_row1_col3, #T_82c43_row1_col4, #T_82c43_row1_col5, #T_82c43_row1_col6, #T_82c43_row1_col7, #T_82c43_row2_col3, #T_82c43_row2_col4, #T_82c43_row2_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_82c43_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_82c43_row2_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_82c43_row2_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_82c43_row2_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# </style>
# <table id="T_82c43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82c43_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_82c43_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_82c43_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_82c43_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_82c43_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_82c43_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_82c43_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_82c43_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82c43_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_82c43_row0_col0" class="data row0 col0" >99457.000000</td>
#       <td id="T_82c43_row0_col1" class="data row0 col1" >43.427089</td>
#       <td id="T_82c43_row0_col2" class="data row0 col2" >14.990054</td>
#       <td id="T_82c43_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_82c43_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_82c43_row0_col5" class="data row0 col5" >43.000000</td>
#       <td id="T_82c43_row0_col6" class="data row0 col6" >56.000000</td>
#       <td id="T_82c43_row0_col7" class="data row0 col7" >69.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82c43_level0_row1" class="row_heading level0 row1" >quantity</th>
#       <td id="T_82c43_row1_col0" class="data row1 col0" >99457.000000</td>
#       <td id="T_82c43_row1_col1" class="data row1 col1" >3.003429</td>
#       <td id="T_82c43_row1_col2" class="data row1 col2" >1.413025</td>
#       <td id="T_82c43_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_82c43_row1_col4" class="data row1 col4" >2.000000</td>
#       <td id="T_82c43_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_82c43_row1_col6" class="data row1 col6" >4.000000</td>
#       <td id="T_82c43_row1_col7" class="data row1 col7" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82c43_level0_row2" class="row_heading level0 row2" >price</th>
#       <td id="T_82c43_row2_col0" class="data row2 col0" >99457.000000</td>
#       <td id="T_82c43_row2_col1" class="data row2 col1" >689.256321</td>
#       <td id="T_82c43_row2_col2" class="data row2 col2" >941.184567</td>
#       <td id="T_82c43_row2_col3" class="data row2 col3" >5.230000</td>
#       <td id="T_82c43_row2_col4" class="data row2 col4" >45.450000</td>
#       <td id="T_82c43_row2_col5" class="data row2 col5" >203.300000</td>
#       <td id="T_82c43_row2_col6" class="data row2 col6" >1200.320000</td>
#       <td id="T_82c43_row2_col7" class="data row2 col7" >5250.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.isna().sum()/len(df)
# Out:
# invoice_no        0.0
# customer_id       0.0
# gender            0.0
# age               0.0
# category          0.0
# quantity          0.0
# price             0.0
# payment_method    0.0
# invoice_date      0.0
# shopping_mall     0.0
# dtype: float64

# %% [markdown]
# No null value in the dataset

# %%
sns.pairplot(df,hue='gender')

# %%
for i in df.columns:
    print(i,'->',df[i].nunique())
# Out:
# invoice_no -> 99457
# customer_id -> 99457
# gender -> 2
# age -> 52
# category -> 8
# quantity -> 5
# price -> 40
# payment_method -> 3
# invoice_date -> 797
# shopping_mall -> 10

# %%
print("The Gender in the dataset",end='')
print(df['gender'].unique())
print("The Category in the dataset",end='')
print(df['category'].unique())
print("The Payment methods in the dataset",end='')
print(df['payment_method'].unique())
print("The shopping malls in the dataset",end='')
print(df['shopping_mall'].unique())
# Out:
# The Gender in the dataset['Female' 'Male']
# The Category in the dataset['Clothing' 'Shoes' 'Books' 'Cosmetics' 'Food & Beverage' 'Toys'
#  'Technology' 'Souvenir']
# The Payment methods in the dataset['Credit Card' 'Debit Card' 'Cash']
# The shopping malls in the dataset['Kanyon' 'Forum Istanbul' 'Metrocity' 'Metropol AVM' 'Istinye Park'
#  'Mall of Istanbul' 'Emaar Square Mall' 'Cevahir AVM' 'Viaport Outlet'
#  'Zorlu Center']

# %%
sns.heatmap(df.corr(),annot=True,cmap='ocean_r')
# Out:
# <Axes: >

# %%
df.hist(figsize=(15,3))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'quantity'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Category count

# %%
ax=df['category'].value_counts().sort_index().plot(kind='bar',title='Category Visualisation',figsize=(16,7),color=color[5],edgecolor='black',linewidth=2)
ax.set_xlabel("Category")
ax.set_ylabel("Count of the value")
# Out:
# Text(0, 0.5, 'Count of the value')

# %% [markdown]
# Gender Visualisation

# %%
gender=df['gender'].value_counts().plot(kind='pie',labels=df['gender'].value_counts().index,autopct='%1.1f%%',wedgeprops=dict(width=0.3,edgecolor='w'))

# %%
# each age gender distribution
df.groupby('age')['gender'].value_counts().sort_index().unstack().style.background_gradient(axis=0,cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_24567_row0_col0, #T_24567_row14_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_24567_row0_col1, #T_24567_row34_col0, #T_24567_row43_col1 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_24567_row1_col0, #T_24567_row35_col0 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_24567_row1_col1 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# #T_24567_row2_col0 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_24567_row2_col1, #T_24567_row24_col1 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_24567_row3_col0 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_24567_row3_col1 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
# }
# #T_24567_row4_col0 {
#   background-color: #f84628;
#   color: #f1f1f1;
# }
# #T_24567_row4_col1, #T_24567_row19_col0, #T_24567_row25_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_24567_row5_col0 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_24567_row5_col1 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_24567_row6_col0, #T_24567_row17_col1 {
#   background-color: #feb24c;
#   color: #000000;
# }
# #T_24567_row6_col1 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_24567_row7_col0 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_24567_row7_col1, #T_24567_row48_col0 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_24567_row8_col0 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_24567_row8_col1, #T_24567_row10_col1 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_24567_row9_col0 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_24567_row9_col1, #T_24567_row18_col1 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_24567_row10_col0 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_24567_row11_col0 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_24567_row11_col1, #T_24567_row32_col1 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_24567_row12_col0 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_24567_row12_col1 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_24567_row13_col0 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_24567_row13_col1 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_24567_row14_col0, #T_24567_row19_col1, #T_24567_row43_col0 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_24567_row15_col0, #T_24567_row40_col1 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_24567_row15_col1 {
#   background-color: #ea2920;
#   color: #f1f1f1;
# }
# #T_24567_row16_col0 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_24567_row16_col1, #T_24567_row23_col1, #T_24567_row51_col0 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_24567_row17_col0 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_24567_row18_col0 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_24567_row20_col0, #T_24567_row24_col0, #T_24567_row42_col0 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_24567_row20_col1 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_24567_row21_col0, #T_24567_row49_col1 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_24567_row21_col1, #T_24567_row34_col1 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_24567_row22_col0 {
#   background-color: #e9261f;
#   color: #f1f1f1;
# }
# #T_24567_row22_col1 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_24567_row23_col0 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_24567_row25_col0 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_24567_row26_col0 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_24567_row26_col1 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_24567_row27_col0 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_24567_row27_col1, #T_24567_row32_col0 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_24567_row28_col0, #T_24567_row47_col1 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_24567_row28_col1, #T_24567_row33_col1 {
#   background-color: #fc572c;
#   color: #f1f1f1;
# }
# #T_24567_row29_col0, #T_24567_row36_col0, #T_24567_row45_col0 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_24567_row29_col1 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_24567_row30_col0 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_24567_row30_col1 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_24567_row31_col0 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_24567_row31_col1, #T_24567_row42_col1 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_24567_row33_col0 {
#   background-color: #fc552c;
#   color: #f1f1f1;
# }
# #T_24567_row35_col1, #T_24567_row38_col1 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_24567_row36_col1 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_24567_row37_col0 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_24567_row37_col1 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_24567_row38_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_24567_row39_col0 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_24567_row39_col1 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_24567_row40_col0 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_24567_row41_col0 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_24567_row41_col1 {
#   background-color: #fd8a3b;
#   color: #f1f1f1;
# }
# #T_24567_row44_col0 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_24567_row44_col1, #T_24567_row50_col0 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_24567_row45_col1 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_24567_row46_col0 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
# }
# #T_24567_row46_col1 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_24567_row47_col0 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_24567_row48_col1 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_24567_row49_col0 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_24567_row50_col1 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_24567_row51_col1 {
#   background-color: #feb852;
#   color: #000000;
# }
# </style>
# <table id="T_24567" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th id="T_24567_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_24567_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24567_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_24567_row0_col0" class="data row0 col0" >1079</td>
#       <td id="T_24567_row0_col1" class="data row0 col1" >765</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_24567_row1_col0" class="data row1 col0" >1133</td>
#       <td id="T_24567_row1_col1" class="data row1 col1" >803</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_24567_row2_col0" class="data row2 col0" >1102</td>
#       <td id="T_24567_row2_col1" class="data row2 col1" >742</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_24567_row3_col0" class="data row3 col0" >1166</td>
#       <td id="T_24567_row3_col1" class="data row3 col1" >781</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row4" class="row_heading level0 row4" >22</th>
#       <td id="T_24567_row4_col0" class="data row4 col0" >1208</td>
#       <td id="T_24567_row4_col1" class="data row4 col1" >843</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row5" class="row_heading level0 row5" >23</th>
#       <td id="T_24567_row5_col0" class="data row5 col0" >1095</td>
#       <td id="T_24567_row5_col1" class="data row5 col1" >802</td>
#     </tr>
#     <tr>
#       <th id="T_24567_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_24567_row6_col0" class="data row6 col0" >1155</td>
#       <td id="T_24567_row6_col1" class="data row6 col1" >822</td>
#     </tr>
#     <tr>

# %%
# Price distribution along with gender
plt.subplots(1,2,figsize=(25,6))
plt.subplot(121)
sns.histplot(data=df,bins=20,x='price',kde=True)
plt.subplot(122)
sns.histplot(data=df,x='price',kde=True,hue='gender')
plt.show()

# %%
def ages(a):
   if a>=65:
    return "Senior aged"
   elif a>=45:
    return "Middle aged"
   else:
    return "Adult age"
df['Age_category']=df['age'].apply(ages)
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall Age_category
# 0    Credit Card   05-08-2022          Kanyon    Adult age
# 1     Debit Card   12-12-2021  Forum Istanbul    Adult age
# 2           Cash   09-11-2021       Metrocity    Adult age
# 3    Credit Card   16-05-2021    Metropol AVM  Senior aged
# 4           Cash   24-10-2021          Kanyon  Middle aged

# %%
# Finding the total amount of the each category with respective payment methods
df.groupby('payment_method')['category'].value_counts().sort_index().unstack().style.background_gradient(axis=0,cmap='RdBu_r')
# Out:
# <style type="text/css">
# #T_55e5e_row0_col0, #T_55e5e_row0_col1, #T_55e5e_row0_col2, #T_55e5e_row0_col3, #T_55e5e_row0_col4, #T_55e5e_row0_col5, #T_55e5e_row0_col6, #T_55e5e_row0_col7 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_55e5e_row1_col0 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_55e5e_row1_col1 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_55e5e_row1_col2, #T_55e5e_row1_col4 {
#   background-color: #fbccb4;
#   color: #000000;
# }
# #T_55e5e_row1_col3 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_55e5e_row1_col5 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_55e5e_row1_col6 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_55e5e_row1_col7 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_55e5e_row2_col0, #T_55e5e_row2_col1, #T_55e5e_row2_col2, #T_55e5e_row2_col3, #T_55e5e_row2_col4, #T_55e5e_row2_col5, #T_55e5e_row2_col6, #T_55e5e_row2_col7 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_55e5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >category</th>
#       <th id="T_55e5e_level0_col0" class="col_heading level0 col0" >Books</th>
#       <th id="T_55e5e_level0_col1" class="col_heading level0 col1" >Clothing</th>
#       <th id="T_55e5e_level0_col2" class="col_heading level0 col2" >Cosmetics</th>
#       <th id="T_55e5e_level0_col3" class="col_heading level0 col3" >Food & Beverage</th>
#       <th id="T_55e5e_level0_col4" class="col_heading level0 col4" >Shoes</th>
#       <th id="T_55e5e_level0_col5" class="col_heading level0 col5" >Souvenir</th>
#       <th id="T_55e5e_level0_col6" class="col_heading level0 col6" >Technology</th>
#       <th id="T_55e5e_level0_col7" class="col_heading level0 col7" >Toys</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >payment_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55e5e_level0_row0" class="row_heading level0 row0" >Cash</th>
#       <td id="T_55e5e_row0_col0" class="data row0 col0" >2268</td>
#       <td id="T_55e5e_row0_col1" class="data row0 col1" >15456</td>
#       <td id="T_55e5e_row0_col2" class="data row0 col2" >6674</td>
#       <td id="T_55e5e_row0_col3" class="data row0 col3" >6587</td>
#       <td id="T_55e5e_row0_col4" class="data row0 col4" >4474</td>
#       <td id="T_55e5e_row0_col5" class="data row0 col5" >2211</td>
#       <td id="T_55e5e_row0_col6" class="data row0 col6" >2235</td>
#       <td id="T_55e5e_row0_col7" class="data row0 col7" >4542</td>
#     </tr>
#     <tr>
#       <th id="T_55e5e_level0_row1" class="row_heading level0 row1" >Credit Card</th>
#       <td id="T_55e5e_row1_col0" class="data row1 col0" >1696</td>
#       <td id="T_55e5e_row1_col1" class="data row1 col1" >12025</td>
#       <td id="T_55e5e_row1_col2" class="data row1 col2" >5336</td>
#       <td id="T_55e5e_row1_col3" class="data row1 col3" >5250</td>
#       <td id="T_55e5e_row1_col4" class="data row1 col4" >3553</td>
#       <td id="T_55e5e_row1_col5" class="data row1 col5" >1770</td>
#       <td id="T_55e5e_row1_col6" class="data row1 col6" >1753</td>
#       <td id="T_55e5e_row1_col7" class="data row1 col7" >3548</td>
#     </tr>
#     <tr>
#       <th id="T_55e5e_level0_row2" class="row_heading level0 row2" >Debit Card</th>
#       <td id="T_55e5e_row2_col0" class="data row2 col0" >1017</td>
#       <td id="T_55e5e_row2_col1" class="data row2 col1" >7006</td>
#       <td id="T_55e5e_row2_col2" class="data row2 col2" >3087</td>
#       <td id="T_55e5e_row2_col3" class="data row2 col3" >2939</td>
#       <td id="T_55e5e_row2_col4" class="data row2 col4" >2007</td>
#       <td id="T_55e5e_row2_col5" class="data row2 col5" >1018</td>
#       <td id="T_55e5e_row2_col6" class="data row2 col6" >1008</td>
#       <td id="T_55e5e_row2_col7" class="data row2 col7" >1997</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Extract year, month, day from invoice date
df['invoice_date']=pd.to_datetime(df['invoice_date'])
df['date']=df['invoice_date'].dt.year
df['month']=df['invoice_date'].dt.month
df['day']=df['invoice_date'].dt.day

df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall Age_category  date  month  day
# 0    Credit Card   2022-05-08          Kanyon    Adult age  2022      5    8
# 1     Debit Card   2021-12-12  Forum Istanbul    Adult age  2021     12   12
# 2           Cash   2021-09-11       Metrocity    Adult age  2021      9   11
# 3    Credit Card   2021-05-16    Metropol AVM  Senior aged  2021      5   16
# 4           Cash   2021-10-24          Kanyon  Middle aged  2021     10   24

# %%
df.drop('invoice_date',axis=1) # Removing the invoice date
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method     shopping_mall Age_category  date  month  day
# 0        Credit Card            Kanyon    Adult age  2022      5    8
# 1         Debit Card    Forum Istanbul    Adult age  2021     12   12
# 2               Cash         Metrocity    Adult age  2021      9   11
# 3        Credit Card      Metropol AVM  Senior aged  2021      5   16
# 4               Cash            Kanyon  Middle aged  2021     10   24
# ...              ...               ...          ...   ...    ...  ...
# 99452    Credit Card            Kanyon  Middle aged  2022      9   21
# 99453           Cash    Forum Istanbul    Adult age  2021      9   22
# 99454     Debit Card         Metrocity  Middle aged  2021      3   28
# 99455           Cash      Istinye Park  Middle aged  2021      3   16
# 99456    Credit Card  Mall of Istanbul    Adult age  2022     10   15
#
# [99457 rows x 13 columns]

# %%
# Sales by shopping mall
mall=df.groupby('shopping_mall')['price'].sum().sort_index()\
.sort_values(ascending=True)\
.plot(kind='bar',title='Total amount sale by each shopping mall',figsize=(18,5),color='skyblue',edgecolor='orange',linewidth=2)
mall.set_xlabel('Shopping Mall')
mall.set_ylabel('count of values')
# Out:
# Text(0, 0.5, 'count of values')

# %%
# Shopping mall with payment method with price
pay = df.groupby(['payment_method','shopping_mall'])[['price']].sum().sort_index().unstack().style.background_gradient(axis=0,cmap='vlag_r')
pay
# Out:
# <style type="text/css">
# #T_5da45_row0_col0, #T_5da45_row0_col1, #T_5da45_row0_col2, #T_5da45_row0_col3, #T_5da45_row0_col4, #T_5da45_row0_col5, #T_5da45_row0_col6, #T_5da45_row0_col7, #T_5da45_row0_col8, #T_5da45_row0_col9 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_5da45_row1_col0 {
#   background-color: #d5d9e3;
#   color: #000000;
# }
# #T_5da45_row1_col1 {
#   background-color: #e7e7ec;
#   color: #000000;
# }
# #T_5da45_row1_col2 {
#   background-color: #c3cbda;
#   color: #000000;
# }
# #T_5da45_row1_col3 {
#   background-color: #cbd1de;
#   color: #000000;
# }
# #T_5da45_row1_col4 {
#   background-color: #f1eff2;
#   color: #000000;
# }
# #T_5da45_row1_col5 {
#   background-color: #dadde5;
#   color: #000000;
# }
# #T_5da45_row1_col6 {
#   background-color: #c2cada;
#   color: #000000;
# }
# #T_5da45_row1_col7 {
#   background-color: #d0d5e0;
#   color: #000000;
# }
# #T_5da45_row1_col8 {
#   background-color: #cfd4e0;
#   color: #000000;
# }
# #T_5da45_row1_col9 {
#   background-color: #bac4d6;
#   color: #000000;
# }
# #T_5da45_row2_col0, #T_5da45_row2_col1, #T_5da45_row2_col2, #T_5da45_row2_col3, #T_5da45_row2_col4, #T_5da45_row2_col5, #T_5da45_row2_col6, #T_5da45_row2_col7, #T_5da45_row2_col8, #T_5da45_row2_col9 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5da45" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5da45_level0_col0" class="col_heading level0 col0" colspan="10">price</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >shopping_mall</th>
#       <th id="T_5da45_level1_col0" class="col_heading level1 col0" >Cevahir AVM</th>
#       <th id="T_5da45_level1_col1" class="col_heading level1 col1" >Emaar Square Mall</th>
#       <th id="T_5da45_level1_col2" class="col_heading level1 col2" >Forum Istanbul</th>
#       <th id="T_5da45_level1_col3" class="col_heading level1 col3" >Istinye Park</th>
#       <th id="T_5da45_level1_col4" class="col_heading level1 col4" >Kanyon</th>
#       <th id="T_5da45_level1_col5" class="col_heading level1 col5" >Mall of Istanbul</th>
#       <th id="T_5da45_level1_col6" class="col_heading level1 col6" >Metrocity</th>
#       <th id="T_5da45_level1_col7" class="col_heading level1 col7" >Metropol AVM</th>
#       <th id="T_5da45_level1_col8" class="col_heading level1 col8" >Viaport Outlet</th>
#       <th id="T_5da45_level1_col9" class="col_heading level1 col9" >Zorlu Center</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >payment_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5da45_level0_row0" class="row_heading level0 row0" >Cash</th>
#       <td id="T_5da45_row0_col0" class="data row0 col0" >1519323.380000</td>
#       <td id="T_5da45_row0_col1" class="data row0 col1" >1546176.250000</td>
#       <td id="T_5da45_row0_col2" class="data row0 col2" >1429764.280000</td>
#       <td id="T_5da45_row0_col3" class="data row0 col3" >3012008.820000</td>
#       <td id="T_5da45_row0_col4" class="data row0 col4" >6205221.670000</td>
#       <td id="T_5da45_row0_col5" class="data row0 col5" >6241779.560000</td>
#       <td id="T_5da45_row0_col6" class="data row0 col6" >4552782.390000</td>
#       <td id="T_5da45_row0_col7" class="data row0 col7" >3103319.490000</td>
#       <td id="T_5da45_row0_col8" class="data row0 col8" >1545471.680000</td>
#       <td id="T_5da45_row0_col9" class="data row0 col9" >1549183.460000</td>
#     </tr>
#     <tr>
#       <th id="T_5da45_level0_row1" class="row_heading level0 row1" >Credit Card</th>
#       <td id="T_5da45_row1_col0" class="data row1 col0" >1202292.160000</td>
#       <td id="T_5da45_row1_col1" class="data row1 col1" >1166797.400000</td>
#       <td id="T_5da45_row1_col2" class="data row1 col2" >1183614.050000</td>
#       <td id="T_5da45_row1_col3" class="data row1 col3" >2386228.050000</td>
#       <td id="T_5da45_row1_col4" class="data row1 col4" >4660884.630000</td>
#       <td id="T_5da45_row1_col5" class="data row1 col5" >4842875.830000</td>
#       <td id="T_5da45_row1_col6" class="data row1 col6" >3677033.180000</td>
#       <td id="T_5da45_row1_col7" class="data row1 col7" >2450575.980000</td>
#       <td id="T_5da45_row1_col8" class="data row1 col8" >1211440.880000</td>
#       <td id="T_5da45_row1_col9" class="data row1 col9" >1269734.770000</td>
#     </tr>
#     <tr>
#       <th id="T_5da45_level0_row2" class="row_heading level0 row2" >Debit Card</th>
#       <td id="T_5da45_row2_col0" class="data row2 col0" >712056.300000</td>
#       <td id="T_5da45_row2_col1" class="data row2 col1" >677434.660000</td>
#       <td id="T_5da45_row2_col2" class="data row2 col2" >722695.490000</td>
#       <td id="T_5da45_row2_col3" class="data row2 col3" >1318840.670000</td>
#       <td id="T_5da45_row2_col4" class="data row2 col4" >2844648.940000</td>
#       <td id="T_5da45_row2_col5" class="data row2 col5" >2767082.230000</td>
#       <td id="T_5da45_row2_col6" class="data row2 col6" >2020164.500000</td>
#       <td id="T_5da45_row2_col7" class="data row2 col7" >1384097.520000</td>
#       <td id="T_5da45_row2_col8" class="data row2 col8" >657106.900000</td>
#       <td id="T_5da45_row2_col9" class="data row2 col9" >690730.790000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Shopping category based on Age category
df.groupby('Age_category')['category'].value_counts().sort_index().unstack().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_b0da9_row0_col0, #T_b0da9_row0_col1, #T_b0da9_row0_col2, #T_b0da9_row0_col3, #T_b0da9_row0_col4, #T_b0da9_row0_col5, #T_b0da9_row0_col6, #T_b0da9_row0_col7 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col0 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col1 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col2, #T_b0da9_row1_col4 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col3, #T_b0da9_row1_col5 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col6 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_b0da9_row1_col7 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_b0da9_row2_col0, #T_b0da9_row2_col1, #T_b0da9_row2_col2, #T_b0da9_row2_col3, #T_b0da9_row2_col4, #T_b0da9_row2_col5, #T_b0da9_row2_col6, #T_b0da9_row2_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b0da9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >category</th>
#       <th id="T_b0da9_level0_col0" class="col_heading level0 col0" >Books</th>
#       <th id="T_b0da9_level0_col1" class="col_heading level0 col1" >Clothing</th>
#       <th id="T_b0da9_level0_col2" class="col_heading level0 col2" >Cosmetics</th>
#       <th id="T_b0da9_level0_col3" class="col_heading level0 col3" >Food & Beverage</th>
#       <th id="T_b0da9_level0_col4" class="col_heading level0 col4" >Shoes</th>
#       <th id="T_b0da9_level0_col5" class="col_heading level0 col5" >Souvenir</th>
#       <th id="T_b0da9_level0_col6" class="col_heading level0 col6" >Technology</th>
#       <th id="T_b0da9_level0_col7" class="col_heading level0 col7" >Toys</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0da9_level0_row0" class="row_heading level0 row0" >Adult age</th>
#       <td id="T_b0da9_row0_col0" class="data row0 col0" >2570</td>
#       <td id="T_b0da9_row0_col1" class="data row0 col1" >18040</td>
#       <td id="T_b0da9_row0_col2" class="data row0 col2" >7802</td>
#       <td id="T_b0da9_row0_col3" class="data row0 col3" >7779</td>
#       <td id="T_b0da9_row0_col4" class="data row0 col4" >5196</td>
#       <td id="T_b0da9_row0_col5" class="data row0 col5" >2637</td>
#       <td id="T_b0da9_row0_col6" class="data row0 col6" >2653</td>
#       <td id="T_b0da9_row0_col7" class="data row0 col7" >5301</td>
#     </tr>
#     <tr>
#       <th id="T_b0da9_level0_row1" class="row_heading level0 row1" >Middle aged</th>
#       <td id="T_b0da9_row1_col0" class="data row1 col0" >1936</td>
#       <td id="T_b0da9_row1_col1" class="data row1 col1" >13206</td>
#       <td id="T_b0da9_row1_col2" class="data row1 col2" >5859</td>
#       <td id="T_b0da9_row1_col3" class="data row1 col3" >5594</td>
#       <td id="T_b0da9_row1_col4" class="data row1 col4" >3898</td>
#       <td id="T_b0da9_row1_col5" class="data row1 col5" >1898</td>
#       <td id="T_b0da9_row1_col6" class="data row1 col6" >1862</td>
#       <td id="T_b0da9_row1_col7" class="data row1 col7" >3799</td>
#     </tr>
#     <tr>
#       <th id="T_b0da9_level0_row2" class="row_heading level0 row2" >Senior aged</th>
#       <td id="T_b0da9_row2_col0" class="data row2 col0" >475</td>
#       <td id="T_b0da9_row2_col1" class="data row2 col1" >3241</td>
#       <td id="T_b0da9_row2_col2" class="data row2 col2" >1436</td>
#       <td id="T_b0da9_row2_col3" class="data row2 col3" >1403</td>
#       <td id="T_b0da9_row2_col4" class="data row2 col4" >940</td>
#       <td id="T_b0da9_row2_col5" class="data row2 col5" >464</td>
#       <td id="T_b0da9_row2_col6" class="data row2 col6" >481</td>
#       <td id="T_b0da9_row2_col7" class="data row2 col7" >987</td>
#     </tr>
#   </tbody>
# </table>
